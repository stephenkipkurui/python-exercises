# %% [markdown]
# # Python Import exercises
# ##
# ## Reffer to import_exercises.py file

# %% [markdown]
# # 1). Import and test 3 of the functions from your functions exercise file. Import each function in a different way:

# %%
from functions_exercises import is_vowel

# %%
import functions_exercises

# %%
from functions_exercises import is_consonant as consonants

# %% [markdown]
# # b). Create a file named import_exericses.py. Within this file, use from to import the calculate_tip function directly. Call this function with values you choose and print the result.

# %%
import functions_exercises

# %%
is_vowel
# Out:
# <function functions_exercises.is_vowel(vowels)>

# %%
is_vowel('F')
# Out:
# False

# %%
from functions_exercises import calculate_tip as tip_calculator

# %%
tip_calculator(0.7, 100)
# Out:
# ('The total bill is: $', 70.0)

# %%
from functions_exercises import get_letter_grade

# %%
get_letter_grade(56)
# Out:
# 'F'

# %% [markdown]
# # 3).
#
# # Read about and use the itertools module from the python standard library to help you solve the following problems:
#
# # How many different ways can you combine the letters from "abc" with the numbers 1, 2, and 3?

# %%
from itertools import permutations

my_list = 'abc123'

p = permutations(my_list)

for i in list(p):
    print(i)
# Out:
# ('a', 'b', 'c', '1', '2', '3')
# ('a', 'b', 'c', '1', '3', '2')
# ('a', 'b', 'c', '2', '1', '3')
# ('a', 'b', 'c', '2', '3', '1')
# ('a', 'b', 'c', '3', '1', '2')
# ('a', 'b', 'c', '3', '2', '1')
# ('a', 'b', '1', 'c', '2', '3')
# ('a', 'b', '1', 'c', '3', '2')
# ('a', 'b', '1', '2', 'c', '3')
# ('a', 'b', '1', '2', '3', 'c')
# ('a', 'b', '1', '3', 'c', '2')
# ('a', 'b', '1', '3', '2', 'c')
# ('a', 'b', '2', 'c', '1', '3')
# ('a', 'b', '2', 'c', '3', '1')
# ('a', 'b', '2', '1', 'c', '3')
# ('a', 'b', '2', '1', '3', 'c')
# ('a', 'b', '2', '3', 'c', '1')
# ('a', 'b', '2', '3', '1', 'c')
# ('a', 'b', '3', 'c', '1', '2')
# ('a', 'b', '3', 'c', '2', '1')
# ('a', 'b', '3', '1', 'c', '2')
# ('a', 'b', '3', '1', '2', 'c')
# ('a', 'b', '3', '2', 'c', '1')
# ('a', 'b', '3', '2', '1', 'c')
# ('a', 'c', 'b', '1', '2', '3')
# ('a', 'c', 'b', '1', '3', '2')
# ('a', 'c', 'b', '2', '1', '3')
# ('a', 'c', 'b', '2', '3', '1')
# ('a', 'c', 'b', '3', '1', '2')
# ('a', 'c', 'b', '3', '2', '1')
# ...

# %% [markdown]
# # #   --> How many different combinations are there of 2 letters from "abcd"?

# %%
from itertools import combinations

letter = 'abcd'

letter_2_combinations = combinations(letter, 2)

ltr = [' | '.join(i) for i in letter_2_combinations]

print(ltr)
# Out:
# ['a | b', 'a | c', 'a | d', 'b | c', 'b | d', 'c | d']

# %% [markdown]
# #   --> How many different permutations are there of 2 letters from "abcd"?

# %%
from itertools import permutations

letters = 'abcd'

permute_letters = permutations(letters, 2)

for index in list(permute_letters):
    
    
    print(index)
    
# 12 Combinations
# Out:
# ('a', 'b')
# ('a', 'c')
# ('a', 'd')
# ('b', 'a')
# ('b', 'c')
# ('b', 'd')
# ('c', 'a')
# ('c', 'b')
# ('c', 'd')
# ('d', 'a')
# ('d', 'b')
# ('d', 'c')

# %% [markdown]
# # 3 Save this file as profiles.json inside of your exercises directory (right click -> save file as...).

# %%
import json

json.load(open('profiles.json'))
# Out:
# [{'_id': '54e23c3e46ab53a440b580e8',
#   'index': 0,
#   'guid': '9962b468-ef3e-4993-b677-617469bc3008',
#   'isActive': False,
#   'balance': '$2,097.02',
#   'picture': 'http://placehold.it/32x32',
#   'age': 39,
#   'eyeColor': 'blue',
#   'name': 'Hebert Estes',
#   'gender': 'male',
#   'company': 'ANDRYX',
#   'email': 'hebertestes@andryx.com',
#   'phone': '+1 (866) 456-2268',
#   'address': '121 Emmons Avenue, Klondike, Kentucky, 5975',
#   'about': 'Sit cillum deserunt irure laboris tempor fugiat laboris. Amet commodo amet est incididunt. Dolore qui fugiat cillum pariatur dolore excepteur elit ipsum.\r\n',
#   'registered': '2014-11-10T01:44:03 +06:00',
#   'latitude': -80.157843,
#   'longitude': 161.93016,
#   'tags': ['sit', 'occaecat', 'non', 'ea', 'sit', 'laboris', 'exercitation'],
#   'friends': [{'id': 0, 'name': 'Tanisha Leonard'},
#    {'id': 1, 'name': 'Dennis Wilson'},
#    {'id': 2, 'name': 'Lupe Howe'}],
# ...

# %%
Total number of users
Number of active users
Number of inactive users
Grand total of balances for all users
Average balance per user
User with the lowest balance
User with the highest balance
Most common favorite fruit
Least most common favorite fruit
Total number of unread messages for all users

# %%
Number of active users

# %%
active_count = 0

in_active_count = 0

for items in data:

    if items['isActive'] == True:

        active_count += 1

#         print('user is Active')
    else:
        in_active_count += 1
#         print('User NOT active')

print(f'The active user\'s count is:{active_count}')
print(f'The active user\'s count is:{in_active_count}')

# %%
Number of inactive users

# %%
active_count = 0

in_active_count = 0

for items in data:

    if items['isActive'] == False:

        in_active_count += 1

#         print('user is Active')
    else:
        active_count += 1
#         print('User NOT active')

print(f'The active user\'s count is:{active_count}')
print(f'The active user\'s count is:{in_active_count}')

# %%
Grand total of balances for all users

# %%
Average balance per user

# %%
User with the lowest balance

# %%
User with the highest balance

# %%
Most common favorite fruit

# %%
Least most common favorite fruit

# %%
Total number of unread messages for all users
